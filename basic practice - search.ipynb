# %%
import os
import sys
sys.path.insert(0, os.path.abspath('../Users/Peter'))

import basicPracticeAlgorithms as bpa


array = [-789,0,4.6765554,234,12,123456]
array = bpa.bubbleSort(array)


#binary search of ints and floats
def binarySearch(x, array):
    
    found = False
    i = 0 
    n = len(array)//2
    
    try:
        while (i != len(array)):
 
            if (array[n] == x):
                found = True
                break
            
            elif (array[n] > x):
                n = n//2
        
            else:
                if (n == 1):
                    n = n+1
                elif (n > len(array)):
                    n = n+1
                else:
                    n = n+(n//2)
            i+=1
            
    except IndexError:
        found = False
    
    if (found):
        return n
    else:
        return None
    #should probably only have one out path ¯\_(ツ)_/¯

    
#finds the second largest element in the array
def second(array):
    fl = 0
    sl = 0
    
    if (len(array) < 2):
        print('Your array is less than 2')
        sl = None
    
    else:
        for i in range(len(array)):
        
            if (i == 0):
                fl = array[i]
                continue
        
            if (array[i] > fl):
                sl = fl
                fl = array[i]
        
            elif (fl > array[i] > sl):
                sl = array[i]
        
    return sl

word = 'onimonopia'

#remove all occurances of a character in a string
def remove(a, word):
    i = 0
    
    while(i < len(word)):

        if (word[i] == a):
            word = word[:i] + word[i+1:]
            i-=1
        i+=1
            
    return word

#check if a number is a prime
def prime(n):
    x = True
    
    if ((n == 0) or (n == 1)):
        x = False
    else:
        i=2
        while(i <= n/2):
        
            if (n%i == 0):
                x = False
                break
        
            i+=1
    
    return x
# Out:
# False
