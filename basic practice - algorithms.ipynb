# %%
#basic practice
#algorithms
#by Peter Voller

#returns boolean to see if element is in array
def match(element, array):
    
    if (element in array):
        return True
    else:
        return False
    
#bubble sorts array    
def bubbleSort(array):
    try:
        isDone = False
    
        while (isDone == False):
            c = 0
            for i in range(len(array)-1):
                if (array[i] > array[i+1]):
                    temp = array[i]
                    array[i] = array[i+1]
                    array[i+1] = temp
                else:
                    c+=1
            
            if (c == len(array)-1):
                isDone = True
        
    except TypeError:
        print("Make sure there are no strings in your array")
    
    return array


#inerstion sort algorithm  
def insertionSort(array):
    try:
        for i in range(1,len(array)):
            j = i 
            while (j > 0) and (array[j-1] > array[j]):
                temp = array[j]
                array[j] = array[j-1]
                array[j-1] = temp
                j -= 1
                
    except TypeError:
        print("Make sure there are no strings in your array")
        
    return array

        

def reverse(array):
    a = []
    for i in range(len(array)):
        a.append(array.pop(-1))
    
    return a
        
#swap two variables with using a third
def swap(a, b):
    b += a
    a = b-a
    b = b -a
    
    return a,b
    
    
#prints fibinnaci sequence using recursion
def fib(first, second):
    
    print(first)
    if (first == 0):
        second = 1
    
    fib(second, first+second)
    
    
#find the factorial of a number
#Logic error when True and False are input
def factorial(number):
    try:
        n = 1
        for i in range(1,number+1):
            n *= i
        
        return n
    
    except TypeError:
        print('Make sure you entered a number')
        return number

    
    
print(factorial(array))
# Out:
# Make sure you entered a number
# [2, 5342, 234, 643, 234, 8763, -234, 4564, 0.4, 69.5, 'h', True]
